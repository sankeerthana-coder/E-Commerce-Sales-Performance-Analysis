# %%
import pandas as pd
d=pd.read_csv("C:\\Users\\laksh\\OneDrive\\Desktop\\E-Commerce Sales Analytics.csv")
df=pd.DataFrame(d)

# %%
df
# Out:
#       order_id  order_date  customer_id product_category region  quantity  \
# 0        10001  01-01-2022         1102           Beauty  South         7
# 1        10002  01-02-2022         1435         Clothing  South         7
# 2        10003  01-03-2022         1860           Beauty   East         3
# 3        10004  01-04-2022         1270      Electronics   West         5
# 4        10005  01-05-2022         1106         Clothing   West         5
# ...        ...         ...          ...              ...    ...       ...
# 4995     14996  09-05-2035         1289         Clothing   West         2
# 4996     14997  09-06-2035         1294           Beauty  North         3
# 4997     14998  09-07-2035         1450           Beauty   West         3
# 4998     14999  09-08-2035         1903      Electronics  South         4
# 4999     15000  09-09-2035         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
print(df.dtypes)
# Out:
# order_id              int64
# order_date              str
# customer_id           int64
# product_category        str
# region                  str
# quantity              int64
# unit_price          float64
# discount            float64
# payment_method          str
# delivery_days         int64
# customer_rating     float64
# revenue             float64
# dtype: object

# %%
df.head(5)
# Out:
#    order_id  order_date  customer_id product_category region  quantity  \
# 0     10001  01-01-2022         1102           Beauty  South         7
# 1     10002  01-02-2022         1435         Clothing  South         7
# 2     10003  01-03-2022         1860           Beauty   East         3
# 3     10004  01-04-2022         1270      Electronics   West         5
# 4     10005  01-05-2022         1106         Clothing   West         5
#
#    unit_price  discount payment_method  delivery_days  customer_rating  \
# 0      373.65      0.28         Wallet             10              4.7
# 1       47.74      0.09           Card              6              3.9
# 2      311.28      0.31            COD              6              2.5
# 3      524.47      0.02         Wallet              6              1.6
# 4      139.87      0.33         Wallet              4              4.9
#
#    revenue
# 0  1883.20
# 1   304.10
# 2   644.35
# 3  2569.90
# 4   468.56

# %%
df.tail(5)
# Out:
#       order_id  order_date  customer_id product_category region  quantity  \
# 4995     14996  09-05-2035         1289         Clothing   West         2
# 4996     14997  09-06-2035         1294           Beauty  North         3
# 4997     14998  09-07-2035         1450           Beauty   West         3
# 4998     14999  09-08-2035         1903      Electronics  South         4
# 4999     15000  09-09-2035         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# 4995      371.74      0.27            COD              3              2.3
# 4996      553.67      0.14            COD             11              2.2
# 4997       77.22      0.24         Wallet              6              3.4
# 4998      138.41      0.21            COD              4              2.8
# 4999      231.58      0.34            COD              5              3.9
#
#       revenue
# 4995   542.74
# 4996  1428.47
# 4997   176.06
# ...

# %%
df.shape
# Out:
# (5000, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          5000 non-null   int64
#  1   order_date        5000 non-null   str
#  2   customer_id       5000 non-null   int64
#  3   product_category  5000 non-null   str
#  4   region            5000 non-null   str
#  5   quantity          5000 non-null   int64
#  6   unit_price        5000 non-null   float64
#  7   discount          5000 non-null   float64
#  8   payment_method    5000 non-null   str
#  9   delivery_days     5000 non-null   int64
#  10  customer_rating   5000 non-null   float64
#  11  revenue           5000 non-null   float64
# dtypes: float64(4), int64(4), str(4)
# memory usage: 596.2 KB

# %%
df.describe()
# Out:
#            order_id  customer_id     quantity   unit_price     discount  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean   12500.500000  1505.701200     4.044800   308.418774     0.179984
# std     1443.520003   290.836902     2.020398   169.259369     0.101404
# min    10001.000000  1000.000000     1.000000    15.150000     0.000000
# 25%    11250.750000  1253.000000     2.000000   161.895000     0.090000
# 50%    12500.500000  1510.000000     4.000000   309.890000     0.180000
# 75%    13750.250000  1761.000000     6.000000   455.557500     0.270000
# max    15000.000000  1999.000000     7.000000   599.960000     0.350000
#
#        delivery_days  customer_rating      revenue
# count    5000.000000      5000.000000  5000.000000
# mean        6.118800         2.973980  1021.955148
# std         3.153264         1.157722   825.584219
# min         1.000000         1.000000    11.210000
# 25%         3.000000         2.000000   354.527500
# ...

# %%
df.sort_values("customer_rating")
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 4511     14512 2034-05-09         1000      Electronics  North         1
# 586      10587 2023-08-10         1046         Clothing  North         7
# 2465     12466 2028-10-01         1989      Electronics  South         5
# 631      10632 2023-09-24         1998         Clothing  North         4
# 633      10634 2023-09-26         1446      Electronics   East         3
# ...        ...        ...          ...              ...    ...       ...
# 1904     11905 2027-03-20         1490         Clothing  South         5
# 3617     13618 2031-11-27         1396             Home   East         2
# 4940     14941 2035-07-12         1900           Beauty   West         4
# 2193     12194 2028-01-03         1954             Home   East         3
# 2217     12218 2028-01-27         1223           Beauty  North         2
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df.sort_values("product_category")
# Out:
#       order_id  order_date  customer_id product_category region  quantity  \
# 0        10001  01-01-2022         1102           Beauty  South         7
# 2        10003  01-03-2022         1860           Beauty   East         3
# 7        10008  01-08-2022         1020           Beauty  North         6
# 12       10013   1/13/2022         1330           Beauty  South         7
# 52       10053   2/22/2022         1875           Beauty   East         1
# ...        ...         ...          ...              ...    ...       ...
# 4990     14991   8/31/2035         1012             Home   East         1
# 4991     14992  09-01-2035         1183             Home  North         2
# 4992     14993  09-02-2035         1110             Home  North         2
# 4994     14995  09-04-2035         1507             Home  South         6
# 4999     15000  09-09-2035         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
df.dropna()
# Out:
#       order_id  order_date  customer_id product_category region  quantity  \
# 0        10001  01-01-2022         1102           Beauty  South         7
# 1        10002  01-02-2022         1435         Clothing  South         7
# 2        10003  01-03-2022         1860           Beauty   East         3
# 3        10004  01-04-2022         1270      Electronics   West         5
# 4        10005  01-05-2022         1106         Clothing   West         5
# ...        ...         ...          ...              ...    ...       ...
# 4995     14996  09-05-2035         1289         Clothing   West         2
# 4996     14997  09-06-2035         1294           Beauty  North         3
# 4997     14998  09-07-2035         1450           Beauty   West         3
# 4998     14999  09-08-2035         1903      Electronics  South         4
# 4999     15000  09-09-2035         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df.drop(columns="revenue")
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001 2022-01-01         1102           Beauty  South         7
# 1        10002 2022-01-02         1435         Clothing  South         7
# 2        10003 2022-01-03         1860           Beauty   East         3
# 3        10004 2022-01-04         1270      Electronics   West         5
# 4        10005 2022-01-05         1106         Clothing   West         5
# ...        ...        ...          ...              ...    ...       ...
# 4995     14996 2035-09-05         1289         Clothing   West         2
# 4996     14997 2035-09-06         1294           Beauty  North         3
# 4997     14998 2035-09-07         1450           Beauty   West         3
# 4998     14999 2035-09-08         1903      Electronics  South         4
# 4999     15000 2035-09-09         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df.drop(columns="revenue")
# Out:
#       order_id  order_date  customer_id product_category region  quantity  \
# 0        10001  01-01-2022         1102           Beauty  South         7
# 1        10002  01-02-2022         1435         Clothing  South         7
# 2        10003  01-03-2022         1860           Beauty   East         3
# 3        10004  01-04-2022         1270      Electronics   West         5
# 4        10005  01-05-2022         1106         Clothing   West         5
# ...        ...         ...          ...              ...    ...       ...
# 4995     14996  09-05-2035         1289         Clothing   West         2
# 4996     14997  09-06-2035         1294           Beauty  North         3
# 4997     14998  09-07-2035         1450           Beauty   West         3
# 4998     14999  09-08-2035         1903      Electronics  South         4
# 4999     15000  09-09-2035         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating
# ...

# %%
df["revenue"]=df["quantity"]*df["unit_price"]

# %%
df
# Out:
#       order_id  order_date  customer_id product_category region  quantity  \
# 0        10001  01-01-2022         1102           Beauty  South         7
# 1        10002  01-02-2022         1435         Clothing  South         7
# 2        10003  01-03-2022         1860           Beauty   East         3
# 3        10004  01-04-2022         1270      Electronics   West         5
# 4        10005  01-05-2022         1106         Clothing   West         5
# ...        ...         ...          ...              ...    ...       ...
# 4995     14996  09-05-2035         1289         Clothing   West         2
# 4996     14997  09-06-2035         1294           Beauty  North         3
# 4997     14998  09-07-2035         1450           Beauty   West         3
# 4998     14999  09-08-2035         1903      Electronics  South         4
# 4999     15000  09-09-2035         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df
# Out:
#       order_id  order_date  customer_id product_category region  quantity  \
# 0        10001  01-01-2022         1102           Beauty  South         7
# 1        10002  01-02-2022         1435         Clothing  South         7
# 2        10003  01-03-2022         1860           Beauty   East         3
# 3        10004  01-04-2022         1270      Electronics   West         5
# 4        10005  01-05-2022         1106         Clothing   West         5
# ...        ...         ...          ...              ...    ...       ...
# 4995     14996  09-05-2035         1289         Clothing   West         2
# 4996     14997  09-06-2035         1294           Beauty  North         3
# 4997     14998  09-07-2035         1450           Beauty   West         3
# 4998     14999  09-08-2035         1903      Electronics  South         4
# 4999     15000  09-09-2035         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df["order_date"]=pd.to_datetime(df["order_date"],format="mixed")

# %%
df
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001 2022-01-01         1102           Beauty  South         7
# 1        10002 2022-01-02         1435         Clothing  South         7
# 2        10003 2022-01-03         1860           Beauty   East         3
# 3        10004 2022-01-04         1270      Electronics   West         5
# 4        10005 2022-01-05         1106         Clothing   West         5
# ...        ...        ...          ...              ...    ...       ...
# 4995     14996 2035-09-05         1289         Clothing   West         2
# 4996     14997 2035-09-06         1294           Beauty  North         3
# 4997     14998 2035-09-07         1450           Beauty   West         3
# 4998     14999 2035-09-08         1903      Electronics  South         4
# 4999     15000 2035-09-09         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df["order_date"].head()
# Out:
# 0   2022-01-01
# 1   2022-01-02
# 2   2022-01-03
# 3   2022-01-04
# 4   2022-01-05
# Name: order_date, dtype: datetime64[us]

# %%
df["order_date"].head(100)
# Out:
# 0    2022-01-01
# 1    2022-01-02
# 2    2022-01-03
# 3    2022-01-04
# 4    2022-01-05
#         ...
# 95   2022-04-06
# 96   2022-04-07
# 97   2022-04-08
# 98   2022-04-09
# 99   2022-04-10
# Name: order_date, Length: 100, dtype: datetime64[us]

# %%
df["Year"] = df["order_date"].dt.year

# %%
df
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001 2022-01-01         1102           Beauty  South         7
# 1        10002 2022-01-02         1435         Clothing  South         7
# 2        10003 2022-01-03         1860           Beauty   East         3
# 3        10004 2022-01-04         1270      Electronics   West         5
# 4        10005 2022-01-05         1106         Clothing   West         5
# ...        ...        ...          ...              ...    ...       ...
# 4995     14996 2035-09-05         1289         Clothing   West         2
# 4996     14997 2035-09-06         1294           Beauty  North         3
# 4997     14998 2035-09-07         1450           Beauty   West         3
# 4998     14999 2035-09-08         1903      Electronics  South         4
# 4999     15000 2035-09-09         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df["Month_name"]=df["order_date"].dt.month_name()

# %%
df
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001 2022-01-01         1102           Beauty  South         7
# 1        10002 2022-01-02         1435         Clothing  South         7
# 2        10003 2022-01-03         1860           Beauty   East         3
# 3        10004 2022-01-04         1270      Electronics   West         5
# 4        10005 2022-01-05         1106         Clothing   West         5
# ...        ...        ...          ...              ...    ...       ...
# 4995     14996 2035-09-05         1289         Clothing   West         2
# 4996     14997 2035-09-06         1294           Beauty  North         3
# 4997     14998 2035-09-07         1450           Beauty   West         3
# 4998     14999 2035-09-08         1903      Electronics  South         4
# 4999     15000 2035-09-09         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df["month"]=df["order_date"].dt.month

# %%
df
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001 2022-01-01         1102           Beauty  South         7
# 1        10002 2022-01-02         1435         Clothing  South         7
# 2        10003 2022-01-03         1860           Beauty   East         3
# 3        10004 2022-01-04         1270      Electronics   West         5
# 4        10005 2022-01-05         1106         Clothing   West         5
# ...        ...        ...          ...              ...    ...       ...
# 4995     14996 2035-09-05         1289         Clothing   West         2
# 4996     14997 2035-09-06         1294           Beauty  North         3
# 4997     14998 2035-09-07         1450           Beauty   West         3
# 4998     14999 2035-09-08         1903      Electronics  South         4
# 4999     15000 2035-09-09         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001 2022-01-01         1102           Beauty  South         7
# 1        10002 2022-01-02         1435         Clothing  South         7
# 2        10003 2022-01-03         1860           Beauty   East         3
# 3        10004 2022-01-04         1270      Electronics   West         5
# 4        10005 2022-01-05         1106         Clothing   West         5
# ...        ...        ...          ...              ...    ...       ...
# 4995     14996 2035-09-05         1289         Clothing   West         2
# 4996     14997 2035-09-06         1294           Beauty  North         3
# 4997     14998 2035-09-07         1450           Beauty   West         3
# 4998     14999 2035-09-08         1903      Electronics  South         4
# 4999     15000 2035-09-09         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
total_revenue=df["revenue"].sum()
print(total_revenue)
# Out:
# 6240021.96

# %%
category_revenue=df.groupby("product_category")["revenue"].sum()
print(category_revenue)
# Out:
# product_category
# Beauty          933359.92
# Clothing       1887131.50
# Electronics    2223312.57
# Home           1196217.97
# Name: revenue, dtype: float64

# %%
product_sales=df.groupby("product_category")["quantity"].sum()
print(product_sales)
# Out:
# product_category
# Beauty         2995
# Clothing       6171
# Electronics    7109
# Home           3949
# Name: quantity, dtype: int64

# %%
monthly_sales=df.groupby("month")["revenue"].sum()
print(monthly_sales)
# Out:
# month
# 1     527122.69
# 2     499459.12
# 3     519296.22
# 4     487268.36
# 5     594801.06
# 6     540767.33
# 7     536574.72
# 8     559293.15
# 9     493188.83
# 10    496311.72
# 11    497812.14
# 12    488126.62
# Name: revenue, dtype: float64

# %%
top_product=df.groupby("product_category")["revenue"].sum().sort_values(ascending=False).head(10)
print(top_product)
# Out:
# product_category
# Electronics    2223312.57
# Clothing       1887131.50
# Home           1196217.97
# Beauty          933359.92
# Name: revenue, dtype: float64

# %%
top_customer=df.groupby("customer_id")["quantity"].sum().sort_values(ascending=False).head(5)
print(top_customer)
# Out:
# customer_id
# 1663    63
# 1957    57
# 1675    55
# 1935    51
# 1276    50
# Name: quantity, dtype: int64

# %%
top_customer=df.groupby("customer_id")["revenue"].sum().sort_values(ascending=False).head(5)
print(top_customer)
# Out:
# customer_id
# 1663    22546.44
# 1955    19218.45
# 1647    18574.98
# 1675    18404.11
# 1836    17489.11
# Name: revenue, dtype: float64

# %%
region_sales = df.groupby("region")["revenue"].sum().sort_values(ascending=False)
print(region_sales)
# Out:
# region
# West     1640762.01
# North    1566659.99
# South    1517429.39
# East     1515170.57
# Name: revenue, dtype: float64

# %%
apply_function=df["revenue"].apply(lambda x: x+1000)
print(apply_function)
# Out:
# 0       3615.55
# 1       1334.18
# 2       1933.84
# 3       3622.35
# 4       1699.35
#          ...
# 4995    1743.48
# 4996    2661.01
# 4997    1231.66
# 4998    1553.64
# 4999    2621.06
# Name: revenue, Length: 5000, dtype: float64

# %%
df["month"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4995    9
# 4996    9
# 4997    9
# 4998    9
# 4999    9
# Name: month, Length: 5000, dtype: int32

# %%
df["total_price"]=df["quantity"]*df["unit_price"]

# %%
df
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001 2022-01-01         1102           Beauty  South         7
# 1        10002 2022-01-02         1435         Clothing  South         7
# 2        10003 2022-01-03         1860           Beauty   East         3
# 3        10004 2022-01-04         1270      Electronics   West         5
# 4        10005 2022-01-05         1106         Clothing   West         5
# ...        ...        ...          ...              ...    ...       ...
# 4995     14996 2035-09-05         1289         Clothing   West         2
# 4996     14997 2035-09-06         1294           Beauty  North         3
# 4997     14998 2035-09-07         1450           Beauty   West         3
# 4998     14999 2035-09-08         1903      Electronics  South         4
# 4999     15000 2035-09-09         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df.drop(columns="total_price",inplace=True)

# %%
df
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001 2022-01-01         1102           Beauty  South         7
# 1        10002 2022-01-02         1435         Clothing  South         7
# 2        10003 2022-01-03         1860           Beauty   East         3
# 3        10004 2022-01-04         1270      Electronics   West         5
# 4        10005 2022-01-05         1106         Clothing   West         5
# ...        ...        ...          ...              ...    ...       ...
# 4995     14996 2035-09-05         1289         Clothing   West         2
# 4996     14997 2035-09-06         1294           Beauty  North         3
# 4997     14998 2035-09-07         1450           Beauty   West         3
# 4998     14999 2035-09-08         1903      Electronics  South         4
# 4999     15000 2035-09-09         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df["cost_price"] = df["unit_price"] * 0.70

# %%
df
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001 2022-01-01         1102           Beauty  South         7
# 1        10002 2022-01-02         1435         Clothing  South         7
# 2        10003 2022-01-03         1860           Beauty   East         3
# 3        10004 2022-01-04         1270      Electronics   West         5
# 4        10005 2022-01-05         1106         Clothing   West         5
# ...        ...        ...          ...              ...    ...       ...
# 4995     14996 2035-09-05         1289         Clothing   West         2
# 4996     14997 2035-09-06         1294           Beauty  North         3
# 4997     14998 2035-09-07         1450           Beauty   West         3
# 4998     14999 2035-09-08         1903      Electronics  South         4
# 4999     15000 2035-09-09         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df["Expenses"] = df["quantity"] * df["cost_price"]

# %%
df
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001 2022-01-01         1102           Beauty  South         7
# 1        10002 2022-01-02         1435         Clothing  South         7
# 2        10003 2022-01-03         1860           Beauty   East         3
# 3        10004 2022-01-04         1270      Electronics   West         5
# 4        10005 2022-01-05         1106         Clothing   West         5
# ...        ...        ...          ...              ...    ...       ...
# 4995     14996 2035-09-05         1289         Clothing   West         2
# 4996     14997 2035-09-06         1294           Beauty  North         3
# 4997     14998 2035-09-07         1450           Beauty   West         3
# 4998     14999 2035-09-08         1903      Electronics  South         4
# 4999     15000 2035-09-09         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
df["Profit_Loss"] = df["revenue"] - df["Expenses"]

# %%
df
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001 2022-01-01         1102           Beauty  South         7
# 1        10002 2022-01-02         1435         Clothing  South         7
# 2        10003 2022-01-03         1860           Beauty   East         3
# 3        10004 2022-01-04         1270      Electronics   West         5
# 4        10005 2022-01-05         1106         Clothing   West         5
# ...        ...        ...          ...              ...    ...       ...
# 4995     14996 2035-09-05         1289         Clothing   West         2
# 4996     14997 2035-09-06         1294           Beauty  North         3
# 4997     14998 2035-09-07         1450           Beauty   West         3
# 4998     14999 2035-09-08         1903      Electronics  South         4
# 4999     15000 2035-09-09         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# ...

# %%
payment_method_analysis=df["payment_method"].value_counts()
print(payment_method_analysis)
# Out:
# payment_method
# Card      2270
# COD       1774
# Wallet     956
# Name: count, dtype: int64

# %%
df.to_csv("C:\\Users\\laksh\\OneDrive\\Desktop\\E-Commerce Sales Analytics.csv", index=False)
